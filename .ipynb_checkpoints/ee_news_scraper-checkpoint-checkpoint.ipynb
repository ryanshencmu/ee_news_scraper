# %%
#Scraper packages
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

#Data Cleaning
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime 
import itertools
import re

#Data Science
from textblob import TextBlob

#Text analysis
import gensim
from gensim.utils import simple_preprocess
import nltk
from nltk.draw.dispersion import dispersion_plot
from nltk.collocations import *
from nltk.tokenize import sent_tokenize, wordpunct_tokenize
from nltk.corpus import stopwords
import pyLDAvis.gensim
import pyLDAvis # Visualize the topics
import gensim.corpora as corpora# Create Dictionary
from pprint import pprint# number of topics
from gensim.models.coherencemodel import CoherenceModel

#OS Packages
import os
from pathlib import Path
import pickle 
from distutils.version import LooseVersion
from collections import Counter

#Suppressing warnings over out of date packages
import warnings
warnings.filterwarnings("ignore")

#Wordcloud
from wordcloud import WordCloud# Join the different processed titles together.

# %%
#Modules I had to download onto my machine for this project
#nltk.download('punkt')
#nltk.download('stopwords')
#!pip install pyLDAvis

# %% [markdown]
# <h1>House Representative Members: Data Scraping and Cleaning</h1>
# <h3>As an option we can use this link to get environmental scorecard data #https://scorecard.lcv.org/members-of-congress</h3>

# %%
def get_house_representatives():
    
    def custom_date_parser(value): #This function is encapsulated because it's customized for this particular dataframe
    try:
        return pd.to_datetime(value, format='%Y')
    except:
        return pd.to_datetime(1900, format='%Y')
    
    driver = webdriver.Firefox() #Ensuring that we move the geckodriver to the user/bin prior to running
    driver.get('https://en.wikipedia.org/wiki/List_of_current_members_of_the_United_States_House_of_Representatives')
    house_members = driver.find_element_by_xpath('//*[@id="votingmembers"]')
    rows = house_members.find_elements_by_tag_name("tr")
    member_info = []
    district_info = []
    for row in rows:
        info_cells = row.find_elements_by_tag_name("td")
        district_cells = row.find_elements_by_tag_name("th")
        for cell in info_cells:
            member_info.append(cell.text)
        for cell_d in district_cells:
            district_info.append(cell_d.text)
    #District namves have the same tag as a table header, so let's separate the table headers from the district names
    col_names, districts = district_info[0:8],district_info[8:]
    col_names[-1] = 'Birthdate'
    col_names[0:2] = col_names[0:2][::-1]
    #There will be some blanks because the district names go by different tags, so we have to populate the missing values in our list with the district names
    count = 0
    for i in range(0,len(member_info)):
        if member_info[i] == '':
            member_info[i] = districts[count]
            count += 1
        if member_info[i] == 'VACANT':
            member_info.remove('VACANT')
            member_info.append([districts[count]])
            for i in range(0,7):
                member_info.append('No House Member')
            count += 1
    house_array = np.reshape(np.array(member_info),(int(len(member_info)/8),8)) #Reshaping the array from one long list into an 8 by 8 matrix
    house_df = pd.DataFrame(house_array,columns = col_names)
    #Splitting birthdate into age and DOB
    birthdate = house_df.Birthdate.apply(lambda x: str(x).split(' ('))
    date_format = '%B %d, %Y'
    birth = []
    ages = []
    for row in birthdate:
        try:
            birth.append(datetime.strptime(row[0], date_format))
            a = re.findall(r'\d*', row[1])
            age = ''.join(a)
            ages.append(int(age))
        except:
            birth.append(datetime.strptime('January 1, 1900', date_format))
            ages.append(0)

    house_df['Birthdate'] = pd.Series(birth)
    house_df['Age'] = pd.Series(ages)
    #Now let's clean the prior experience and education columns where we have new lines
    house_df['Prior experience'] = house_df['Prior experience'].apply(lambda x: x.replace('\n',' '))
    house_df['Education'] = house_df['Education'].apply(lambda x: x.replace('\n',' '))

    '''#Now we're going to turn the remainder of the variables into categorical variables
    try:
        cat = ['Member','District','Party']
        for col in cat:
            house_df[col] = pd.Categorical(house_df[col])
    except:
        pass
    '''
    house_df['Assumed office'] = house_df['Assumed office'].apply(custom_date_parser)
    driver.close()
    return house_df

# %%
#Optional link to League of Conservation Database and comparing indicators in their census tract

# %%
#Create a scraper that scans the headlines for EE News Articles, 
#Conduct LDA and topic modeling, and possibly connects the municipalities mentioned in the text to census facts or their congressmen’s action on energy justice issues
#Getting information regarding voting records

# %% [markdown]
# <h1> Scraping EE News for the past year </h1>

# %%
driver = webdriver.Firefox(executable_path=r'/Users/ryanshen/opt/anaconda3/bin/geckodriver')

# %%
def article_dataframes():
    heading_names = []
    url_list = [] #We will be collecting a list of urls
    author_dates = []
    for page in range(1,50):
        driver.get('https://www.eenews.net/publication/energywire/page/'+ str(page) +'/')
        headings = driver.find_elements_by_tag_name("h4") #first we take all the headings on the landing page
        for heading in headings:
            heading_names.append(heading.text)
        urls = driver.find_elements_by_tag_name("a")
        for url in urls: #then we grab all the urls
            if url.text == 'Read More >>': #Read More >> tagline is necessary to prevent duplication of URLs since every article on the webpage has two hyperlinks 
                url_list.append(url.get_attribute('href')) #Add the hyperlink to a list
        author_date = driver.find_elements_by_tag_name('p')
        for entry in author_date:
            if entry.text[0:2] == 'BY': #All author date combos are denoted with the keyword BY
                author_dates.append(entry.text)
    author_and_dates = author_dates[1::]
    authors = [author.split('|')[0][3:-1] for author in author_and_dates]
    dates = [date.split('|')[1][1:-4] for date in author_and_dates]
    
    def str_split(string):
        article = string.split(' ')[0]
        date_format = '%m/%d/%Y'
        return datetime.strptime(article, date_format)
        
    pub_date = list(map(str_split, dates))
#    date_format = '%B %d, %Y'
#    pub_date = []
#    pub_date = [datetime.strptime(article, date_format) for article in date_w_out_time]
    
    rows = []
    
    for i in range(0,len(url_list)):
        rows.append([heading_names[i], url_list[i], authors[i], pub_date[i]])
    articles = pd.DataFrame(rows, columns = ['headings', 'url', 'author', 'pub_date'])
    #Create a function that takes the text from every URL
    return articles

# %%
ee_news = article_dataframes()

# %%
print(ee_news.dtypes)
# Out:
# headings            object
# url                 object
# author              object
# pub_date    datetime64[ns]
# dtype: object

# %%
def get_text(url):
        paragraph = ''
        driver.get(url)
        sent_elem = driver.find_elements_by_tag_name('p')#getting the sentence elements off the page
        sent_elem = sent_elem[1::]
        for sentences in sent_elem:
            paragraph += sentences.text
        return paragraph
ee_news['text'] = ee_news['url'].apply(lambda x: get_text(x))

# %%
#Now we want to convert all cases to lowercase and remove punctuation prior to tokenization
ee_news.text = ee_news['text'].map(lambda x: re.sub('[,\.!?]', '', x)) 
ee_news.text = ee_news['text'].map(lambda x: x.lower())

driver.close() #We've scraped all the text we've needed

# %%
ee_news.to_pickle('ee_news.pkl') #Converting to pickle so we don't have to scrape again

# %% [markdown]
# <h1> Performing Topic Modeling on EE News Text </h1>

# %%
#If reading this from pickle, run this cell
ee_news = pd.read_pickle('/Users/ryanshen/Desktop/Projects/House_Voting/House-Voting/ee_news.pkl')

# %%
ee_news.head()
print(len(ee_news))
# Out:
# 443

# %%
#Need to run a generator if trying to get author counts over time

# %% [markdown]
# <h4> We're now going to prime our dataframe for text analysis using <a href = https://towardsdatascience.com/end-to-end-topic-modeling-in-python-latent-dirichlet-allocation-lda-35ce4ed6b3e0>LDA </a> </h4>

# %%
#Idea: Create heading clusters to see what the most popular topics are. Google topic modeling
stop_words = stopwords.words('english') #First we load the english stopwords
stop_words.extend(['from','by', 'subject', 'politico', 'photos', '/', 'said', 'would','could']) #Here's where we have the option to remove stop words

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        # deacc=True removes punctuations
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))
        
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

data = ee_news.text.values.tolist()
data_words = list(sent_to_words(data))
data_words = remove_stopwords(data_words)

print(data_words[:1][0][:30])
# Out:
# ['claudine', 'hellmuth', 'illustration', 'freepik', 'stock', 'ticker', 'money', 'oil', 'barrels', 'shelby', 'webb', 'news', 'orphaned', 'well', 'pecos', 'county', 'texas', 'hard', 'gag', 'first', 'smelling', 'sulfur', 'emanating', 'boehmer', 'lake', 'middle', 'scrubby', 'desert', 'herethe', 'acre']

# %%
ee_news['tokenized_text'] = data_words

# %%
id2word = corpora.Dictionary(data_words)# Create Corpus
texts = data_words# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]# View
print(corpus[:1][0][:30])
# Out:
# [(0, 1), (1, 4), (2, 1), (3, 1), (4, 2), (5, 1), (6, 1), (7, 2), (8, 2), (9, 3), (10, 1), (11, 1), (12, 1), (13, 4), (14, 1), (15, 1), (16, 2), (17, 1), (18, 5), (19, 1), (20, 1), (21, 1), (22, 1), (23, 1), (24, 1), (25, 1), (26, 4), (27, 1), (28, 2), (29, 3)]

# %%
num_topics = 10# Build LDA model. We might need to experiment to see what the ideal number of topics is
lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=num_topics)# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.014*"energy" + 0.008*"new" + 0.007*"gas" + 0.006*"wind" + 0.005*"power" + '
#   '0.005*"state" + 0.004*"us" + 0.004*"oil" + 0.004*"climate" + 0.004*"also"'),
#  (1,
#   '0.009*"energy" + 0.007*"gas" + 0.006*"power" + 0.006*"state" + 0.005*"new" '
#   '+ 0.004*"electric" + 0.004*"also" + 0.003*"companies" + 0.003*"natural" + '
#   '0.003*"one"'),
#  (2,
#   '0.015*"energy" + 0.010*"power" + 0.007*"gas" + 0.007*"new" + 0.004*"solar" '
#   '+ 0.004*"wind" + 0.004*"also" + 0.004*"federal" + 0.004*"grid" + '
#   '0.004*"clean"'),
#  (3,
#   '0.011*"gas" + 0.010*"energy" + 0.006*"new" + 0.006*"oil" + 0.006*"power" + '
#   '0.005*"us" + 0.004*"year" + 0.004*"climate" + 0.004*"administration" + '
#   '0.004*"state"'),
#  (4,
#   '0.009*"gas" + 0.007*"energy" + 0.006*"new" + 0.006*"power" + 0.004*"state" '
#   '+ 0.004*"also" + 0.004*"federal" + 0.003*"grid" + 0.003*"natural" + '
#   '0.003*"us"'),
#  (5,
#   '0.010*"energy" + 0.007*"gas" + 0.005*"new" + 0.005*"us" + 0.004*"power" + '
#   '0.004*"also" + 0.004*"biden" + 0.004*"state" + 0.004*"solar" + 0.003*"oil"'),
#  (6,
#   '0.012*"energy" + 0.008*"new" + 0.008*"state" + 0.007*"gas" + 0.006*"also" + '
#   '0.006*"power" + 0.005*"oil" + 0.004*"grid" + 0.004*"federal" + '
#   '0.003*"wind"'),
#  (7,
#   '0.010*"energy" + 0.008*"state" + 0.007*"power" + 0.007*"gas" + '
#   '0.005*"climate" + 0.004*"new" + 0.004*"carbon" + 0.004*"administration" + '
#   '0.004*"biden" + 0.003*"natural"'),
#  (8,
#   '0.012*"energy" + 0.006*"new" + 0.006*"power" + 0.006*"gas" + 0.005*"state" '
#   '+ 0.005*"also" + 0.004*"year" + 0.004*"climate" + 0.004*"electric" + '
#   '0.004*"solar"'),
#  (9,
#   '0.012*"energy" + 0.007*"gas" + 0.006*"state" + 0.005*"new" + 0.005*"power" '
#   '+ 0.004*"us" + 0.004*"wind" + 0.004*"also" + 0.004*"climate" + '
#   '0.004*"year"')]

# %% [markdown]
# <h4>Now we're going to determine the optimal number of topics by maximizing topic coherence.</h4>
#
# <p>Here's a <a href = 'https://radimrehurek.com/gensim/models/coherencemodel.html'> reference </a> to the gensim api, and here's a <a href = https://tedboy.github.io/nlps/_modules/gensim/models/coherencemodel.html> link </a> to the source code. <a href = https://towardsdatascience.com/understanding-topic-coherence-measures-4aa41339634c>Here's</a> a descriptive explanation of how topic modeling works.</p>
#
# <p>If you're not familiar with how topic modeling works, after confirming the number of topics, we examine our tokens to see if any of them have a high probability of being identified as a group across the entire corpus. (While topic modeling rarely examines relationships between more than two words, it is possible for three or more words to be identified as a relevant group.)
#
# The probability of two or more words being associated is also known as a confirmation measure.
#
# After taking all the confirmation measures between each of the most important words in the topic, the confirmation measures are aggregated. The aggregate confirmation measure is the coherence score for the topic.
# </p>

# %%
num_topics = range(2,30) #Trying from 2 to 30 clusters
coherence_scores = []

for n in num_topics:
    lda_model_test = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=n)
    cm = CoherenceModel(model=lda_model_test, corpus=corpus, coherence='u_mass') #u_mass is the fastest of the options to place within the coherence argument
    coherence = cm.get_coherence()  # get coherence value
    coherence_scores.append(coherence)

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(2,30), coherence_scores, marker='o')
plt.axvline(x=2+coherence_scores.index(np.max(coherence_scores)), color='red', linestyle='--')
plt.title('Coherence Scores for LDA')
plt.xlabel('Number of Topics')
plt.ylabel('Coherence Scores')
plt.grid(True)
plt.show()

# %%
num_topics = coherence_scores.index(np.max(coherence_scores)) + 2
print('The ideal number of topics is', num_topics)
# Out:
# The ideal number of topics is 3

# %%
other_corpus
# Out:
# [[(209, 1), (258, 1), (446, 1)],
#  [(1854, 1), (3664, 1)],
#  [(656, 1), (2621, 1), (9789, 1)]]

# %%
pyLDAvis.enable_notebook()

#We want to save the path as an absolute path when we initiate deserialization to lower the odds that the program will raise an error if the path name is too long/gets corrupted
LDAvis_data_filepath = Path('energy_news_scraper').absolute()
#LDAvis_data_filepath = os.path.join('./results/ldavis_prepared_'+str(num_topics))
os.makedirs(os.path.dirname(LDAvis_data_filepath), exist_ok=True)
print(type(str(LDAvis_data_filepath)))
# Out:
# <class 'str'>

# %%
dict_tokens = id2word.token2id #Presents a dictinoary of the tokens with their token_ids
token_freq = id2word.dfs #gets the frequency of different tokens within total documents, but this only seems to measure how many articles have the token rather than how many times these tokens are referenced

merged = {}
for key, count in dict_tokens.items():
    merged.update({key:token_freq[count]})

# %%
sorted_dict = sorted(merged.items(), key = lambda x:x[1], reverse = True)

# %%
sorted_dict
# Out:
# [('llc', 443),
#  ('energy', 427),
#  ('also', 424),
#  ('new', 407),
#  ('year', 382),
#  ('us', 375),
#  ('last', 361),
#  ('federal', 347),
#  ('one', 346),
#  ('gas', 341),
#  ('according', 330),
#  ('power', 325),
#  ('years', 321),
#  ('time', 319),
#  ('may', 314),
#  ('like', 312),
#  ('two', 308),
#  ('industry', 306),
#  ('president', 305),
#  ('states', 304),
#  ('climate', 303),
#  ('state', 301),
#  ('director', 300),
#  ('biden', 298),
#  ('clean', 296),
#  ('administration', 296),
#  ('including', 296),
#  ('percent', 291),
#  ('public', 290),
#  ('part', 286),
#  ('make', 286),
#  ('need', 282),
#  ('long', 280),
#  ('first', 276),
#  ('companies', 274),
#  ('natural', 273),
#  ('say', 273),
#  ('even', 273),
#  ('going', 272),
#  ('policy', 270),
#  ('still', 270),
#  ('many', 267),
#  ('electric', 267),
#  ('projects', 264),
#  ('much', 263),
#  ('help', 263),
#  ('energywire', 262),
#  ('department', 261),
#  ('get', 256),
#  ('environmental', 254),
#  ('well', 254),
#  ('national', 251),
#  ('high', 250),
#  ('act', 249),
#  ('future', 246),
#  ('law', 245),
#  ('way', 244),
#  ('whether', 243),
#  ('take', 242),
#  ('use', 242),
#  ('group', 241),
#  ('called', 239),
#  ('joe', 239),
#  ('carbon', 239),
#  ('company', 237),
#  ('think', 237),
#  ('fuel', 237),
#  ('million', 231),
#  ('renewable', 230),
#  ('change', 229),
#  ('fossil', 229),
#  ('project', 227),
#  ('emissions', 225),
#  ('across', 220),
#  ('cost', 220),
#  ('country', 219),
#  ('infrastructure', 219),
#  ('made', 219),
#  ('resources', 219),
#  ('support', 219),
#  ('electricity', 218),
#  ('based', 217),
#  ('grid', 217),
#  ('month', 215),
#  ('american', 214),
#  ('billion', 214),
#  ('see', 214),
#  ('come', 214),
#  ('back', 213),
#  ('solar', 212),
#  ('groups', 212),
#  ('statement', 212),
#  ('next', 212),
#  ('three', 211),
#  ('work', 210),
#  ('since', 208),
#  ('already', 207),
#  ('move', 207),
#  ('potential', 206),
#  ('process', 206),
#  ('officials', 205),
#  ('plan', 205),
#  ('recent', 204),
#  ('wind', 204),
#  ('commission', 202),
#  ('news', 202),
#  ('plans', 202),
#  ('major', 202),
#  ('end', 201),
#  ('set', 199),
#  ('another', 197),
#  ('oil', 197),
#  ('development', 197),
#  ('executive', 196),
#  ('united', 196),
#  ('supply', 196),
#  ('regulatory', 196),
#  ('added', 194),
#  ('government', 194),
#  ('production', 194),
#  ('proposed', 194),
#  ('enough', 193),
#  ('costs', 191),
#  ('co', 190),
#  ('people', 190),
#  ('likely', 190),
#  ('build', 189),
#  ('want', 189),
#  ('system', 188),
#  ('house', 187),
#  ('week', 186),
#  ('utility', 186),
#  ('spokesperson', 185),
#  ('association', 185),
#  ('senior', 184),
#  ('utilities', 184),
#  ('plants', 183),
#  ('making', 183),
#  ('large', 182),
#  ('used', 182),
#  ('go', 182),
#  ('several', 182),
#  ('largest', 180),
#  ('less', 180),
#  ('report', 179),
#  ('earlier', 179),
#  ('reduction', 178),
#  ('without', 177),
#  ('demand', 177),
#  ('important', 177),
#  ('least', 176),
#  ('around', 175),
#  ('market', 174),
#  ('key', 173),
#  ('center', 172),
#  ('expected', 171),
#  ('nation', 170),
#  ('transition', 170),
#  ('agency', 169),
#  ('low', 169),
#  ('working', 169),
#  ('inflation', 169),
#  ('goals', 169),
#  ('far', 168),
#  ('meet', 167),
#  ('advocates', 167),
#  ('term', 167),
#  ('example', 166),
#  ('really', 165),
#  ('program', 163),
#  ('require', 163),
#  ('existing', 162),
#  ('lower', 161),
#  ('decision', 161),
#  ('fuels', 161),
#  ('comes', 160),
#  ('however', 160),
#  ('known', 160),
#  ('building', 160),
#  ('office', 160),
#  ('right', 160),
#  ('challenges', 159),
#  ('significant', 159),
#  ('sector', 159),
#  ('concerns', 159),
#  ('issues', 158),
#  ('among', 158),
#  ('congress', 157),
#  ('current', 157),
#  ('along', 157),
#  ('provide', 157),
#  ('continue', 156),
#  ('plant', 156),
#  ('lot', 156),
#  ('issue', 155),
#  ('put', 155),
#  ('generation', 155),
#  ('away', 154),
#  ('ceo', 154),
#  ('needs', 154),
#  ('approved', 154),
#  ('currently', 152),
#  ('greenhouse', 152),
#  ('white', 151),
#  ('comment', 151),
#  ('big', 150),
#  ('keep', 150),
#  ('must', 150),
#  ('clear', 150),
#  ('critical', 150),
#  ('told', 150),
#  ('increase', 149),
#  ('rules', 149),
#  ('bill', 149),
#  ('north', 149),
#  ('needed', 148),
#  ('able', 148),
#  ('found', 147),
#  ('half', 147),
#  ('place', 147),
#  ('released', 147),
#  ('capacity', 147),
#  ('day', 147),
#  ('goal', 146),
#  ('institute', 145),
#  ('corp', 145),
#  ('include', 145),
#  ('technology', 145),
#  ('action', 145),
#  ('case', 145),
#  ('forward', 145),
#  ('five', 144),
#  ('impact', 144),
#  ('might', 143),
#  ('policies', 143),
#  ('using', 143),
#  ('prices', 143),
#  ('trade', 143),
#  ('zero', 142),
#  ('inc', 142),
#  ('led', 142),
#  ('world', 142),
#  ('line', 142),
#  ('service', 142),
#  ('june', 142),
#  ('little', 141),
#  ('regulators', 141),
#  ('nearly', 141),
#  ('become', 140),
#  ('lead', 140),
#  ('point', 140),
#  ('west', 140),
#  ('general', 139),
#  ('water', 139),
#  ('announced', 139),
#  ('university', 139),
#  ('level', 138),
#  ('yet', 138),
#  ('council', 138),
#  ('saidthe', 137),
#  ('within', 137),
#  ('past', 136),
#  ('wrote', 136),
#  ('analysis', 136),
#  ('republican', 136),
#  ('reduce', 136),
#  ('transmission', 136),
#  ('times', 135),
#  ('tax', 135),
#  ('coal', 135),
#  ('saying', 135),
#  ('research', 135),
#  ('ensure', 134),
#  ('order', 134),
#  ('role', 134),
#  ('today', 134),
#  ('construction', 134),
#  ('four', 134),
#  ('customers', 134),
#  ('investment', 133),
#  ('money', 133),
#  ('proposal', 133),
#  ('months', 133),
#  ('scale', 133),
#  ('getty', 132),
#  ('early', 131),
#  ('every', 131),
#  ('know', 131),
#  ('run', 131),
#  ('question', 130),
#  ('authority', 129),
#  ('create', 129),
#  ('good', 129),
#  ('interview', 129),
#  ('questions', 129),
#  ('toward', 129),
#  ('developers', 129),
#  ('vice', 129),
#  ('coming', 129),
#  ('done', 129),
#  ('reliability', 129),
#  ('open', 129),
#  ('different', 128),
#  ('others', 128),
#  ('per', 128),
#  ('start', 128),
#  ('april', 128),
#  ('address', 128),
#  ('allow', 127),
#  ('look', 127),
#  ('number', 127),
#  ('changes', 127),
#  ('higher', 127),
#  ('better', 127),
#  ('storage', 127),
#  ('price', 126),
#  ('texas', 126),
#  ('seen', 126),
#  ('something', 126),
#  ('experts', 126),
#  ('global', 125),
#  ('free', 125),
#  ('near', 125),
#  ('california', 125),
#  ('additional', 124),
#  ('available', 124),
#  ('former', 124),
#  ('local', 124),
#  ('america', 124),
#  ('built', 124),
#  ('lines', 124),
#  ('challenge', 124),
#  ('given', 123),
#  ('says', 123),
#  ('full', 123),
#  ('members', 123),
#  ('possible', 123),
#  ('areas', 122),
#  ('pipeline', 122),
#  ('review', 122),
#  ('region', 122),
#  ('march', 122),
#  ('business', 121),
#  ('includes', 121),
#  ('cut', 121),
#  ('although', 121),
#  ('renewables', 121),
#  ('amount', 120),
#  ('efforts', 120),
#  ('court', 120),
#  ('came', 120),
#  ('attorney', 119),
#  ('firm', 119),
#  ('passed', 119),
#  ('similar', 119),
#  ('getting', 119),
#  ('decade', 119),
#  ('economic', 118),
#  ('required', 118),
#  ('lawmakers', 118),
#  ('facilities', 117),
#  ('impacts', 117),
#  ('email', 116),
#  ('benefits', 116),
#  ('record', 116),
#  ('senate', 116),
#  ('often', 115),
#  ('planning', 115),
#  ('approach', 115),
#  ('information', 115),
#  ('chair', 115),
#  ('later', 114),
#  ('legislation', 114),
#  ('political', 114),
#  ('taking', 114),
#  ('communities', 113),
#  ('sen', 113),
#  ('best', 113),
#  ('response', 113),
#  ('agencies', 112),
#  ('asked', 112),
#  ('due', 112),
#  ('ap', 112),
#  ('reach', 112),
#  ('area', 111),
#  ('economy', 111),
#  ('remains', 111),
#  ('technologies', 111),
#  ('step', 110),
#  ('recently', 110),
#  ('bring', 110),
#  ('trying', 110),
#  ('quickly', 110),
#  ('jobs', 109),
#  ('management', 109),
#  ('risk', 109),
#  ('short', 109),
#  ('chief', 109),
#  ('legal', 109),
#  ('moving', 109),
#  ('signed', 109),
#  ('air', 109),
#  ('levels', 108),
#  ('independent', 108),
#  ('secretary', 108),
#  ('things', 108),
#  ('means', 107),
#  ('ways', 107),
#  ('story', 107),
#  ('argued', 106),
#  ('give', 106),
#  ('majority', 106),
#  ('parts', 106),
#  ('kind', 106),
#  ('instead', 105),
#  ('requirements', 105),
#  ('site', 105),
#  ('battery', 105),
#  ('data', 105),
#  ('democratic', 105),
#  ('looking', 105),
#  ('strong', 105),
#  ('consumers', 105),
#  ('adding', 104),
#  ('considered', 104),
#  ('hard', 104),
#  ('respond', 104),
#  ('especially', 104),
#  ('push', 104),
#  ('call', 104),
#  ('included', 104),
#  ('ago', 104),
#  ('operators', 103),
#  ('necessary', 103),
#  ('produce', 103),
#  ('standards', 103),
#  ('washington', 103),
#  ('net', 103),
#  ('small', 103),
#  ('benefit', 102),
#  ('environment', 102),
#  ('equipment', 102),
#  ('land', 101),
#  ('took', 101),
#  ('operations', 101),
#  ('final', 101),
#  ('compared', 101),
#  ('certain', 100),
#  ('dollars', 100),
#  ('issued', 100),
#  ('rule', 100),
#  ('growing', 100),
#  ('reliable', 100),
#  ('decades', 100),
#  ('particularly', 100),
#  ('planned', 100),
#  ('investments', 99),
#  ('access', 99),
#  ('though', 99),
#  ('doe', 99),
#  ('ever', 99),
#  ('roughly', 99),
#  ('source', 99),
#  ('control', 99),
#  ('top', 98),
#  ('total', 98),
#  ('beyond', 98),
#  ('noted', 98),
#  ('industries', 98),
#  ('regulations', 98),
#  ('bipartisan', 97),
#  ('district', 97),
#  ('focused', 97),
#  ('got', 97),
#  ('homes', 97),
#  ('focus', 97),
#  ('idea', 97),
#  ('gov', 97),
#  ('problem', 96),
#  ('study', 96),
#  ('wants', 96),
#  ('chain', 96),
#  ('rather', 96),
#  ('summer', 96),
#  ('meeting', 96),
#  ('growth', 95),
#  ('hydrogen', 95),
#  ('interest', 95),
#  ('pay', 95),
#  ('virginia', 95),
#  ('second', 95),
#  ('third', 95),
#  ('miles', 95),
#  ('coast', 95),
#  ('sure', 95),
#  ('south', 94),
#  ('green', 94),
#  ('opportunity', 94),
#  ('systems', 94),
#  ('limited', 94),
#  ('february', 94),
#  ('approval', 94),
#  ('days', 93),
#  ('late', 93),
#  ('face', 93),
#  ('consider', 93),
#  ('security', 93),
#  ('funding', 92),
#  ('democrats', 92),
#  ('trump', 92),
#  ('nuclear', 92),
#  ('sources', 92),
#  ('ahead', 92),
#  ('biggest', 91),
#  ('professor', 91),
#  ('permitting', 91),
#  ('heat', 91),
#  ('increased', 91),
#  ('owned', 91),
#  ('six', 91),
#  ('john', 90),
#  ('result', 90),
#  ('vehicles', 90),
#  ('incentives', 90),
#  ('ability', 89),
#  ('declined', 89),
#  ('left', 89),
#  ('producers', 89),
#  ('huge', 89),
#  ('pipelines', 89),
#  ('committee', 89),
#  ('outside', 89),
#  ('actions', 89),
#  ('july', 88),
#  ('multiple', 88),
#  ('programs', 88),
#  ('release', 88),
#  ('credits', 88),
#  ('close', 88),
#  ('makes', 88),
#  ('home', 87),
#  ('offshore', 87),
#  ('previous', 87),
#  ('reported', 87),
#  ('boost', 87),
#  ('massive', 87),
#  ('resource', 87),
#  ('businesses', 87),
#  ('markets', 87),
#  ('request', 87),
#  ('actually', 86),
#  ('continued', 86),
#  ('republicans', 86),
#  ('vehicle', 86),
#  ('deal', 86),
#  ('online', 86),
#  ('difficult', 86),
#  ('transportation', 86),
#  ('find', 85),
#  ('press', 85),
#  ('remain', 85),
#  ('shift', 85),
#  ('comments', 85),
#  ('problems', 85),
#  ('analysts', 85),
#  ('billions', 85),
#  ('fact', 85),
#  ('fully', 85),
#  ('position', 85),
#  ('hold', 85),
#  ('member', 85),
#  ('larger', 85),
#  ('created', 84),
#  ('private', 84),
#  ('real', 84),
#  ('domestic', 84),
#  ('pressure', 84),
#  ('designed', 84),
#  ('effort', 84),
#  ('ferc', 83),
#  ('raised', 83),
#  ('taken', 83),
#  ('capture', 83),
#  ('represents', 83),
#  ('regional', 83),
#  ('york', 83),
#  ('yesterday', 83),
#  ('cases', 82),
#  ('despite', 82),
#  ('either', 82),
#  ('facing', 82),
#  ('operator', 82),
#  ('expand', 82),
#  ('related', 82),
#  ('specific', 82),
#  ('leaders', 82),
#  ('epa', 82),
#  ('failed', 82),
#  ('chung', 82),
#  ('francis', 82),
#  ('international', 82),
#  ('safety', 82),
#  ('decisions', 82),
#  ('ultimately', 82),
#  ('defense', 81),
#  ('financial', 81),
#  ('petroleum', 81),
#  ('strategy', 81),
#  ('sought', 81),
#  ('seeking', 81),
#  ('fall', 80),
#  ('potentially', 80),
#  ('deliver', 80),
#  ('considering', 80),
#  ('backed', 80),
#  ('community', 80),
#  ('fast', 80),
#  ('play', 80),
#  ('associated', 80),
#  ('buy', 79),
#  ('prevent', 79),
#  ('previously', 79),
#  ('nonprofit', 79),
#  ('direct', 79),
#  ('western', 79),
#  ('mean', 79),
#  ('mix', 79),
#  ('try', 79),
#  ('concern', 79),
#  ('sent', 79),
#  ('reason', 79),
#  ('greenwire', 79),
#  ('happen', 78),
#  ('increasing', 78),
#  ('soon', 78),
#  ('pass', 78),
#  ('never', 78),
#  ('expensive', 78),
#  ('period', 78),
#  ('southern', 78),
#  ('avoid', 78),
#  ('observers', 77),
#  ('requires', 77),
#  ('almost', 77),
#  ('critics', 77),
#  ('head', 77),
#  ('target', 77),
#  ('addition', 77),
#  ('stop', 77),
#  ('industrial', 77),
#  ('laws', 77),
#  ('justice', 77),
#  ('largely', 77),
#  ('manufacturing', 77),
#  ('sense', 77),
#  ('board', 76),
#  ('longer', 76),
#  ('batteries', 76),
#  ('credit', 76),
#  ('everything', 76),
#  ('meanwhile', 76),
#  ('hit', 76),
#  ('advanced', 76),
#  ('extreme', 76),
#  ('steps', 76),
#  ('directly', 76),
#  ('warned', 76),
#  ('initiative', 76),
#  ('letter', 76),
#  ('city', 76),
#  ('following', 75),
#  ('operating', 75),
#  ('solutions', 75),
#  ('david', 75),
#  ('drive', 75),
#  ('held', 75),
#  ('manchin', 75),
#  ('network', 75),
#  ('coalition', 75),
#  ('debate', 75),
#  ('rate', 75),
#  ('average', 74),
#  ('range', 74),
#  ('single', 74),
#  ('turn', 74),
#  ('affect', 74),
#  ('agreement', 74),
#  ('dioxide', 74),
#  ('path', 74),
#  ('efficiency', 74),
#  ('leader', 74),
#  ('overall', 74),
#  ('rising', 74),
#  ('achieve', 74),
#  ('running', 74),
#  ('unclear', 74),
#  ('behind', 73),
#  ('drilling', 73),
#  ('ground', 73),
#  ('staff', 73),
#  ('consumer', 73),
#  ('together', 73),
#  ('mile', 73),
#  ('serve', 73),
#  ('analyst', 73),
#  ('estimated', 73),
#  ('great', 73),
#  ('creating', 72),
#  ('facility', 72),
#  ('protect', 72),
#  ('terms', 72),
#  ('campaign', 72),
#  ('force', 72),
#  ('spending', 72),
#  ('partners', 71),
#  ('workers', 71),
#  ('setting', 71),
#  ('reducing', 71),
#  ('share', 71),
#  ('appears', 71),
#  ('pollution', 71),
#  ('worked', 71),
#  ('show', 71),
#  ('permits', 70),
#  ('whose', 70),
#  ('main', 70),
#  ('fired', 70),
#  ('thing', 70),
#  ('particular', 69),
#  ('priority', 69),
#  ('producing', 69),
#  ('pace', 69),
#  ('road', 69),
#  ('broader', 69),
#  ('columbia', 69),
#  ('filed', 69),
#  ('raise', 69),
#  ('leading', 69),
#  ('reached', 69),
#  ('improve', 69),
#  ('obama', 69),
#  ('rates', 69),
#  ('commercial', 69),
#  ('expect', 69),
#  ('produced', 69),
#  ('climatewire', 69),
#  ('fight', 68),
#  ('photo', 68),
#  ('concerned', 68),
#  ('faced', 68),
#  ('closely', 68),
#  ('regulation', 68),
#  ('add', 68),
#  ('mexico', 68),
#  ('jan', 68),
#  ('central', 67),
#  ('form', 67),
#  ('limit', 67),
#  ('shows', 67),
#  ('started', 67),
#  ('gigawatts', 67),
#  ('separate', 67),
#  ('targets', 67),
#  ('alliance', 67),
#  ('life', 67),
#  ('draft', 67),
#  ('continues', 67),
#  ('gulf', 67),
#  ('greater', 67),
#  ('megawatts', 67),
#  ('version', 67),
#  ('offer', 67),
#  ('thousands', 66),
#  ('job', 66),
#  ('effects', 66),
#  ('entire', 66),
#  ('studies', 66),
#  ('calls', 66),
#  ('conference', 66),
#  ('crisis', 66),
#  ('measures', 66),
#  ('starting', 66),
#  ('democrat', 66),
#  ('effect', 66),
#  ('conditions', 66),
#  ('risks', 66),
#  ('jennifer', 66),
#  ('feb', 66),
#  ('hearing', 65),
#  ('light', 65),
#  ('types', 65),
#  ('went', 65),
#  ('cars', 65),
#  ('countries', 65),
#  ('materials', 65),
#  ('pushed', 65),
#  ('january', 65),
#  ('begin', 65),
#  ('proposals', 65),
#  ('speed', 65),
#  ('vote', 65),
#  ('bills', 65),
#  ('generating', 65),
#  ('export', 65),
#  ('november', 65),
#  ('contributed', 65),
#  ('advocacy', 64),
#  ('bureau', 64),
#  ('december', 64),
#  ('interior', 64),
#  ('mark', 64),
#  ('sales', 64),
#  ('located', 64),
#  ('develop', 64),
#  ('limits', 64),
#  ('pointed', 64),
#  ('science', 64),
#  ('weather', 64),
#  ('organization', 64),
#  ('standard', 64),
#  ('goes', 64),
#  ('old', 64),
#  ('wednesday', 64),
#  ('expansion', 63),
#  ('labor', 63),
#  ('matter', 63),
#  ('panel', 63),
#  ('significantly', 63),
#  ('options', 63),
#  ('ready', 63),
#  ('daily', 63),
#  ('allowed', 62),
#  ('cannot', 62),
#  ('conservation', 62),
#  ('county', 62),
#  ('grow', 62),
#  ('congressional', 62),
#  ('provided', 62),
#  ('aug', 62),
#  ('view', 62),
#  ('opposition', 62),
#  ('side', 62),
#  ('progress', 62),
#  ('always', 62),
#  ('whole', 62),
#  ('commerce', 62),
#  ('began', 61),
#  ('changing', 61),
#  ('determine', 61),
#  ('described', 61),
#  ('ev', 61),
#  ('manufacturers', 61),
#  ('rep', 61),
#  ('researchers', 61),
#  ('tuesday', 61),
#  ('developer', 61),
#  ('provisions', 61),
#  ('developed', 61),
#  ('generally', 61),
#  ('affordable', 61),
#  ('operation', 61),
#  ('ongoing', 61),
#  ('quality', 61),
#  ('rise', 61),
#  ('space', 61),
#  ('latest', 61),
#  ('amid', 61),
#  ('model', 61),
#  ('pushing', 61),
#  ('anything', 61),
#  ('annual', 60),
#  ('fund', 60),
#  ('lands', 60),
#  ('millions', 60),
#  ('operate', 60),
#  ('requests', 60),
#  ('size', 60),
#  ('committed', 60),
#  ('history', 60),
#  ('win', 60),
#  ('appeals', 60),
#  ('sign', 60),
#  ('value', 60),
#  ('takes', 60),
#  ('capital', 60),
#  ('probably', 60),
#  ('methane', 60),
#  ('saidin', 60),
#  ('block', 60),
#  ('estimates', 59),
#  ('apply', 59),
#  ('cause', 59),
#  ('encourage', 59),
#  ('legislative', 59),
#  ('believe', 59),
#  ('cleaner', 59),
#  ('involved', 59),
#  ('helped', 59),
#  ('residents', 59),
#  ('beginning', 59),
#  ('hundreds', 58),
#  ('americans', 58),
#  ('partner', 58),
#  ('owners', 58),
#  ('broad', 58),
#  ('decarbonize', 58),
#  ('factors', 58),
#  ('works', 58),
#  ('advance', 58),
#  ('smaller', 58),
#  ('wide', 58),
#  ('winter', 58),
#  ('arguing', 58),
#  ('judge', 58),
#  ('colorado', 57),
#  ('lack', 57),
#  ('manager', 57),
#  ('th', 57),
#  ('argue', 57),
#  ('supplies', 57),
#  ('war', 57),
#  ('circuit', 57),
#  ('ruling', 57),
#  ('understand', 57),
#  ('decarbonization', 57),
#  ('commitment', 57),
#  ('favor', 57),
#  ('managing', 57),
#  ('mike', 57),
#  ('organizations', 57),
#  ('traditional', 57),
#  ('official', 57),
#  ('granholm', 57),
#  ('ukraine', 57),
#  ('enacted', 56),
#  ('permit', 56),
#  ('affairs', 56),
#  ('calling', 56),
#  ('criticized', 56),
#  ('paying', 56),
#  ('deployment', 56),
#  ('thursday', 56),
#  ('china', 56),
#  ('emerging', 56),
#  ('helping', 56),
#  ('panels', 56),
#  ('typically', 56),
#  ('adviser', 56),
#  ('interconnection', 56),
#  ('established', 56),
#  ('budget', 56),
#  ('ban', 56),
#  ('replace', 56),
#  ('governor', 56),
#  ('competitive', 55),
#  ('criticism', 55),
#  ('funds', 55),
#  ('wave', 55),
#  ('evs', 55),
#  ('agreed', 55),
#  ('finding', 55),
#  ('pretty', 55),
#  ('metric', 55),
#  ('tons', 55),
#  ('opportunities', 55),
#  ('cities', 55),
#  ('efficient', 55),
#  ('increasingly', 55),
#  ('peak', 55),
#  ('lost', 55),
#  ('advantage', 55),
#  ('station', 55),
#  ('health', 55),
#  ('weeks', 55),
#  ('attention', 55),
#  ('oct', 55),
#  ('dec', 55),
#  ('asking', 54),
#  ('became', 54),
#  ('feet', 54),
#  ('received', 54),
#  ('type', 54),
#  ('answer', 54),
#  ('driven', 54),
#  ('meaning', 54),
#  ('capitol', 54),
#  ('cited', 54),
#  ('delay', 54),
#  ('turbines', 54),
#  ('august', 54),
#  ('widespread', 54),
#  ('buildings', 54),
#  ('experience', 54),
#  ('phase', 54),
#  ('events', 54),
#  ('september', 54),
#  ('sell', 54),
#  ('reporters', 54),
#  ('requiring', 53),
#  ('hand', 53),
#  ...]

# %%
# # if you want to execute visualization prep yourself
if 1 == 1:
    lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=num_topics)# Print the Keyword in the 3 topics
    LDAvis_prepared = pyLDAvis.gensim.prepare(lda_model, corpus, id2word) #--> Transforms and prepares data for a LDA transformation
    with open(str(LDAvis_data_filepath), 'wb') as f: #We serialize our data to improve performance and data integrity
        pickle.dump(LDAvis_prepared, f)# load the pre-prepared pyLDAvis data from disk
with open(LDAvis_data_filepath, 'rb') as f:
    LDAvis_prepared = pickle.load(f)

pyLDAvis.save_html(LDAvis_prepared, './results/ldavis_prepared_'+ str(num_topics) +'.html')
LDAvis_prepared
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2      0.002846 -0.002020       1        1  40.497895
# 0     -0.003228 -0.001379       2        1  31.491370
# 1      0.000382  0.003399       3        1  28.010735, topic_info=         Term         Freq        Total Category  logprob  loglift
# 1099    solar  1178.000000  1178.000000  Default  30.0000  30.0000
# 209    energy  4521.000000  4521.000000  Default  29.0000  29.0000
# 1365    power  2473.000000  2473.000000  Default  28.0000  28.0000
# 295     house   540.000000   540.000000  Default  27.0000  27.0000
# 1811     grid  1194.000000  1194.000000  Default  26.0000  26.0000
# ...       ...          ...          ...      ...      ...      ...
# 1159       us   337.974760  1408.558534   Topic3  -5.7990  -0.1548
# 446       oil   354.330776  1544.529744   Topic3  -5.7517  -0.1997
# 641    states   267.052006  1065.686950   Topic3  -6.0345  -0.1113
# 807   climate   295.741965  1428.727891   Topic3  -5.9325  -0.3025
# 1495   carbon   260.464825  1149.282461   Topic3  -6.0595  -0.2118
#
# [287 rows x 6 columns], token_table=       Topic      Freq       Term
# term
# 4          1  0.402823  according
# 4          2  0.361771  according
# 4          3  0.234766  according
# 16479      1  0.544936  adjourned
# 16479      3  0.544936  adjourned
# ...      ...       ...        ...
# 2993       2  0.417060       york
# 2993       3  0.222911       york
# 15560      1  0.240229    yorkers
# 15560      2  0.480459    yorkers
# 15560      3  0.240229    yorkers
#
# [587 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 1, 2])

# %% [markdown]
# Unsurprisingly, each article has a high chance of including words like power, energy, gas, and broad terms related to American, domestic energy policy. More exclusive words can be found the further you reduce lambda. Based on what I've found by setting lambda = 0.2 and 0.08, the topic numbers can be grouped as follows:
# 1. Riskier Renewable Projects that include Offshore Wind and Hydrogen
# 2. Solar Power Generation
# 3. State Energy Policy concerning EVs

# %%
#Train an ensemble LDA model to see if there's better performance
#Source: https://radimrehurek.com/gensim/models/ensemblelda.html

# %%
#Identify topic areas of prime interest and develop a time series of certain topic areas
#Create a lexical dispersion plot
#Source: https://github.com/katreparitosh/Discourse-Analytics-of-Political-Speech-Transcripts

# %%
#Learn about the collections API https://docs.python.org/3/library/collections.html

# %%
#Let's see if we can generate a time series of how often hydrogen is mentinoed in ee_news
# Out:
#       pub_date
# 0   2023-08-17
# 1   2023-08-16
# 2   2023-08-15
# 3   2023-08-14
# 4   2023-08-11
# ..         ...
# 305 2022-05-12
# 306 2022-05-11
# 307 2022-05-10
# 308 2022-05-09
# 309 2022-05-06
#
# [310 rows x 1 columns]

# %%
def create_new_count(*argv):
    df_all_keywords = pd.DataFrame(ee_news.pub_date.unique(), columns = ['pub_date'])
    def col_counter(list_of_words, search_word):
        counter = Counter(list_of_words)
        return counter[search_word]
    
    for keyword in argv:
        ee_news[keyword] = [col_counter(ee_news['tokenized_text'][i], keyword) 
                               for i in range(len(ee_news['tokenized_text']))]
        filter_df = ee_news[['pub_date', keyword]].groupby('pub_date').sum().reset_index()
        df_all_keywords[keyword] = filter_df[keyword]
        
    
    def unlimited_stripplot(dataframe, *column_names, **kwargs):
        # Create a copy of the DataFrame with the selected columns
        selected_data = dataframe[list(column_names)]

        # Reshape the DataFrame for plotting
        melted_df = selected_data.melt(var_name='Key Words', value_name='Frequency')

        # Create a strip plot using seaborn
        sns.stripplot(x='Frequency', y='Key Words', data=melted_df, jitter=True, **kwargs)

        plt.xlabel('Frequency')
        plt.ylabel('Key Words')
        plt.title('Articles that mention Topics')
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()
    
    unlimited_stripplot(ee_news, *argv)

# %%
create_new_count('solar', 'hydrogen', 'wind') #A latency plot will probably be better here

# %% [markdown]
# Here we're creating a lexical dispersion plot, which aims to visualize how often words appear from the begnning of the corpus.

# %%
text = list(itertools.chain(*ee_news.tokenized_text))
all_articles_Text = nltk.Text(text)

# %%
all_articles_Text[0:10]
# Out:
# ['claudine',
#  'hellmuth',
#  'illustration',
#  'freepik',
#  'stock',
#  'ticker',
#  'money',
#  'oil',
#  'barrels',
#  'shelby']

# %%
all_articles_Text.similar('energy')
# Out:
# power electricity hydrogen solar oil wind gas battery electric
# generation interior new transmission state climate resources us
# transportation projects grid

# %%
all_articles_Text.similar('')
# Out:
# biden texas billion many issue mandate might process almost announced
# finished project week certificate broader economy association unlikely
# saying senate

# %%
all_articles_Text.generate()
# Out:
# Building ngram index...
# paper adding eu act block unfair competition china overwhelmingly
# passed bill impose company benefit leases gulf mexico next yearbut
# locals ports across south central us states california city berkeley
# indirectly banned gas heat source buildings particular point
# contention exactly biden administration also commended granholm
# supporting critically needed investment horizon give carbon management
# great plains region according december data us energy world resources
# institute told news recently company target achieve net zero time
# start acting climate hawks though contend hydrogen natural gas exports
# pipeline ship winter expected percent higher cobalt percent higher
# nickel percent higher cobalt percent higher million estimate approved
# 'paper adding eu act block unfair competition china overwhelmingly\npassed bill impose company benefit leases gulf mexico next yearbut\nlocals ports across south central us states california city berkeley\nindirectly banned gas heat source buildings particular point\ncontention exactly biden administration also commended granholm\nsupporting critically needed investment horizon give carbon management\ngreat plains region according december data us energy world resources\ninstitute told news recently company target achieve net zero time\nstart acting climate hawks though contend hydrogen natural gas exports\npipeline ship winter expected percent higher cobalt percent higher\nnickel percent higher cobalt percent higher million estimate approved'

# %%
100 * all_articles_Text.count('energy') / len(all_articles_Text) #Energy takes up 1.2% of total words used in the corpora
# Out:
# 1.2139159527092704

# %%
#Getting lexical richness
len(set(all_articles_Text))/len(all_articles_Text)
# Out:
# 0.0673820055107213

# %%
'''target_words = ['money','energy']

all_articles_Text.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])
#Why is this lexical dispersion plot not graphing any results?
'''

# %%
all_articles_Text.collocations(num = 25)
# Out:
# natural gas; biden administration; clean energy; offshore wind;
# inflation reduction; oil gas; white house; reduction act; united
# states; fossil fuel; last year; mountain valley; renewable energy;
# carbon capture; new york; fossil fuels; greenhouse gas; climate
# change; supreme court; supply chain; west virginia; joe biden; power
# plants; tax credits; vice president

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(all_articles_Text, window_size=7)
finder.nbest(bigram_measures.pmi, 10)
finder.apply_freq_filter(10)
results=finder.nbest(bigram_measures.pmi,100)

# %%
results #We're getting quite a few names
# Out:
# [('edtby', 'edtby'),
#  ('miranda', 'willson'),
#  ('loper', 'bright'),
#  ('carlos', 'anchondo'),
#  ('petra', 'nova'),
#  ('hydraulic', 'fracturing'),
#  ('karine', 'pierre'),
#  ('dormant', 'clause'),
#  ('lisa', 'murkowski'),
#  ('lujan', 'grisham'),
#  ('totalenergies', 'se'),
#  ('karine', 'jean'),
#  ('claudine', 'hellmuth'),
#  ('jean', 'pierre'),
#  ('los', 'angeles'),
#  ('cook', 'inlet'),
#  ('lg', 'chem'),
#  ('pine', 'grove'),
#  ('deb', 'haaland'),
#  ('continental', 'shelf'),
#  ('allison', 'clements'),
#  ('outer', 'continental'),
#  ('degrees', 'fahrenheit'),
#  ('status', 'quo'),
#  ('outer', 'shelf'),
#  ('saudi', 'arabia'),
#  ('ross', 'hopper'),
#  ('gavin', 'newsom'),
#  ('jones', 'albertus'),
#  ('geologic', 'formations'),
#  ('hourly', 'matching'),
#  ('degrees', 'celsius'),
#  ('chuck', 'schumer'),
#  ('combustion', 'engine'),
#  ('chuck', 'ny'),
#  ('permian', 'basin'),
#  ('endangered', 'species'),
#  ('eminent', 'domain'),
#  ('class', 'vi'),
#  ('wood', 'mackenzie'),
#  ('monsell', 'biological'),
#  ('claudine', 'illustration'),
#  ('hellmuth', 'illustration'),
#  ('greg', 'abbott'),
#  ('oral', 'arguments'),
#  ('scott', 'olson'),
#  ('jefferson', 'forest'),
#  ('peskoe', 'harvard'),
#  ('biological', 'diversity'),
#  ('george', 'bush'),
#  ('puerto', 'rico'),
#  ('rhode', 'island'),
#  ('army', 'corps'),
#  ('diablo', 'canyon'),
#  ('natalie', 'cox'),
#  ('debt', 'ceiling'),
#  ('securities', 'exchange'),
#  ('mike', 'soraghan'),
#  ('kathy', 'hochul'),
#  ('midterm', 'elections'),
#  ('non', 'condensing'),
#  ('supplemental', 'eis'),
#  ('exxon', 'mobil'),
#  ('transwest', 'express'),
#  ('shell', 'plc'),
#  ('charlie', 'baker'),
#  ('blog', 'post'),
#  ('sierra', 'club'),
#  ('san', 'juan'),
#  ('san', 'francisco'),
#  ('pensacola', 'dam'),
#  ('iso', 'ne'),
#  ('hyundai', 'kia'),
#  ('paper', 'mill'),
#  ('lithium', 'ion'),
#  ('invaded', 'ukraine'),
#  ('schumer', 'ny'),
#  ('convenience', 'stores'),
#  ('internal', 'combustion'),
#  ('francis', 'chung'),
#  ('justin', 'sullivan'),
#  ('enhanced', 'recovery'),
#  ('bp', 'plc'),
#  ('capitol', 'hill'),
#  ('version', 'misstated'),
#  ('closely', 'watched'),
#  ('wall', 'street'),
#  ('lawrence', 'berkeley'),
#  ('barack', 'obama'),
#  ('southwest', 'pool'),
#  ('pacific', 'northwest'),
#  ('elon', 'musk'),
#  ('modular', 'reactor'),
#  ('justin', 'imagesthe'),
#  ('pore', 'space'),
#  ('leader', 'chuck'),
#  ('ron', 'desantis'),
#  ('rolling', 'blackouts'),
#  ('correction', 'version'),
#  ('modular', 'reactors')]

# %%
#Option, turn every article into its own class
#Inspiration: https://www.geeksforgeeks.org/self-in-python-class/#
